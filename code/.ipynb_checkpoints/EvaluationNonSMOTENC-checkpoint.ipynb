# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter
from sklearn.metrics import classification_report, confusion_matrix, f1_score, make_scorer
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold

from imblearn.over_sampling import BorderlineSMOTE
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.pipeline import Pipeline
from imblearn.base import BaseSampler

from sklearn.compose import ColumnTransformer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, RobustScaler
from sklearn.tree import DecisionTreeClassifier

# %%
X = pd.read_csv("X_data.csv")
y = pd.read_csv("y_data.csv").Status

# %%
numeric_features = ['N_Days', 'Age', 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper',
                   'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin']
categorical_unordered_features = ["Drug", "Sex"]
categorical_ordered_features = ["Ascites", "Hepatomegaly", "Spiders", "Edema", "Stage"]

X = X.reset_index(drop=True)
y = y.reset_index(drop=True)

# %% [markdown]
# The CustomImputers retrive the labels for the KNNImputers and SimpleImputer by matching the indeces of the current X sent by the pipeline and the global y which contains all the labels. Also selects just the rows with the current label.

# %%
class CustomKNNImputer(KNNImputer):
    def __init__(self, n_neighbors=5, weights="uniform", **kwargs):
        super().__init__(n_neighbors=n_neighbors, weights=weights, **kwargs)
        self.n_neighbors = n_neighbors
        self.weights = weights
        global y
        self.y = y.copy()
    
    def fit(self, X, y=None):
        self.imputer_by_class_ = {}
        for cls in self.y.unique():
            #Matching the index of X and global y plus matching the labels
            indices = self.y[self.y.index.isin(X.index) & (self.y == cls)].index
            self.imputer_by_class_[cls] = KNNImputer(n_neighbors=self.n_neighbors, weights=self.weights).fit(X.loc[indices])
        return self
    
    def transform(self, X):
        #print(X.isna().sum())
        for cls, imputer in self.imputer_by_class_.items():
            indices = self.y[self.y.index.isin(X.index) & (self.y == cls)].index
            X.loc[indices] = imputer.transform(X.loc[indices])
        #print(X.isna().sum())
        return X

class CustomSimpleImputer(SimpleImputer):
    def __init__(self, strategy="most_frequent", **kwargs):
        super().__init__(strategy=strategy, **kwargs)
        self.strategy = strategy
        global y
        self.y = y.copy()
        
    def fit(self, X, y=None):
        self.imputer_by_class_ = {}
        for cls in self.y.unique():
            indices = self.y[self.y.index.isin(X.index) & (self.y == cls)].index
            self.imputer_by_class_[cls] = SimpleImputer(strategy=self.strategy).fit(X.loc[indices])
        return self
    
    def transform(self, X):
        #print(X.isna().sum())
        for cls, imputer in self.imputer_by_class_.items():
            indices = self.y[self.y.index.isin(X.index) & (self.y == cls)].index
            X.loc[indices] = imputer.transform(X.loc[indices])
        #print(X.isna().sum())
        return X

# %% [markdown]
# The CustomOrdinalEncoder is created in order to set the correct order for the values since it's not the default behaviour.
# In this case, since the CustomOrdinalEncoder is the first step, in the custom_orders i can use the name of the feature.

# %%
class CustomOrdinalEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, custom_orders):
        self.custom_orders = custom_orders
        self.encoders = {}

    def fit(self, X, y=None):
        for col, categories in self.custom_orders.items():
            encoder = OrdinalEncoder(categories=[categories], handle_unknown='use_encoded_value', unknown_value=-1)
            encoder.fit(X[[col]])
            self.encoders[col] = encoder
        return self

    def transform(self, X):
        for col, encoder in self.encoders.items():
            X[col] = encoder.transform(X[[col]])
        return X
        
custom_orders = {
    'Ascites': ['N', 'Y'],
    'Hepatomegaly': ['N', 'Y'],
    'Spiders': ['N', 'Y'],
    'Edema': ['N', 'S', 'Y'],
    'Stage': ['1.0', '2.0', '3.0', '4.0']
}

# %%
class ENNBSmoteBalancer(BaseSampler):
    def __init__(self, k_neighbors_cleaning=5, k_neighbors_borders=5):
        self.k_neighbors_cleaning = k_neighbors_cleaning
        self.k_neighbors_borders = k_neighbors_borders

    def _fit_resample(self, X, y):
        return self.fit_resample(X, y)
        
    def fit_resample(self, X, y):
        ncl = EditedNearestNeighbours(sampling_strategy=["High chance"], n_neighbors=self.k_neighbors_cleaning)
        X_resampled, y_resampled = ncl.fit_resample(X, y)
        
        borsmote = BorderlineSMOTE(random_state=0, k_neighbors=self.k_neighbors_borders)
        X_resampled, y_resampled = borsmote.fit_resample(X_resampled, y_resampled)
        
        return X_resampled, y_resampled

# %%
class KBestMutualInfoSelector(BaseEstimator, TransformerMixin):
    def __init__(self, k=5, random_state=None):
        self.k = k
        self.random_state = random_state
        
    def fit(self, X, y=None):
        def _mutual_info_classif(X, y):
            return mutual_info_classif(X, y, random_state=self.random_state)
        
        self.selector = SelectKBest(score_func=_mutual_info_classif, k=self.k)
        self.selector.fit(X, y)
        return self
    
    def transform(self, X):
        return self.selector.transform(X)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", Pipeline([
            ("imputer", CustomKNNImputer()),
            ("scaler", RobustScaler())
        ]), numeric_features),
        ("cat_unord", Pipeline([
            ("imputer", CustomSimpleImputer(strategy="most_frequent")),
            ("encoder", OneHotEncoder())
        ]), categorical_unordered_features),
        ("cat_ord", Pipeline([
            ("imputer", CustomSimpleImputer(strategy="most_frequent")),
            ("encoder", CustomOrdinalEncoder(custom_orders))
        ]), categorical_ordered_features)
    ]
)

# %%
clf_RandomForest = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("feature_selector", KBestMutualInfoSelector(random_state=0)),
        ('sampler', ENNBSmoteBalancer()),
        ("classifier", RandomForestClassifier(random_state=0, n_jobs=-1))
    ]
)
clf_KNNeighbor = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("feature_selector", KBestMutualInfoSelector(random_state=0)),
        ('sampler', ENNBSmoteBalancer()),
        ("classifier", KNeighborsClassifier(n_jobs=-1))
    ]
)
clf_AdaBoostGNB = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("feature_selector", KBestMutualInfoSelector(random_state=0)),
        ('sampler', ENNBSmoteBalancer()),
        ("classifier", AdaBoostClassifier(random_state=0, estimator=GaussianNB(), algorithm="SAMME"))
    ]
)
clf_LogReg = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("feature_selector", KBestMutualInfoSelector(random_state=0)),
        ('sampler', ENNBSmoteBalancer()),
        ("classifier", LogisticRegression(random_state=0))
    ]
)

clf_RandomForest
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    CustomKNNImputer()),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['N_Days', 'Age', 'Bilirubin',
#                                                    'Cholesterol', 'Albumin',
#                                                    'Copper', 'Alk_Phos', 'SGOT',
#                                                    'Tryglicerides', 'Platelets',
#                                                    'Prothrombin']),
#                                                  ('cat_unord',
#                                                   Pipeline(steps=[('imputer',
#                                                                    CustomSimpleImputer()),
#                                                                   ('encoder',
#                                                                    OneHotE...
#                                                                    CustomOrdinalEncoder(custom_orders={'Ascites': ['N',
#                                                                                                                    'Y'],
#                                                                                                        'Edema': ['N',
#                                                                                                                  'S',
#                                                                                                                  'Y'],
#                                                                                                        'Hepatomegaly': ['N',
#                                                                                                                         'Y'],
#                                                                                                        'Spiders': ['N',
#                                                                                                                    'Y'],
#                                                                                                        'Stage': ['1.0',
#                                                                                                                  '2.0',
#                                                                                                                  '3.0',
#                                                                                                                  '4.0']}))]),
#                                                   ['Ascites', 'Hepatomegaly',
#                                                    'Spiders', 'Edema',
#                                                    'Stage'])])),
#                 ('feature_selector', KBestMutualInfoSelector(random_state=0)),
#                 ('sampler', ENNBSmoteBalancer()),
#                 ('classifier',
#                  RandomForestClassifier(n_jobs=-1, random_state=0))])

# %%
# RandomForest
param_grid_RandomForest = {
    "preprocessor__num__imputer__n_neighbors": range(3, 16),
    
    "feature_selector__k": range(1, 21),
    
    "sampler__k_neighbors_cleaning": range(3, 10, 2),
    "sampler__k_neighbors_borders": range(3, 10, 2),
    
    "classifier__max_depth": range(2, 8),
    "classifier__criterion": ["gini", "entropy"],
}

# KNNeighbor
param_grid_KNNeighbor = {
    "preprocessor__num__imputer__n_neighbors": range(3, 16),
    
    "feature_selector__k": range(1, 21),
    
    "sampler__k_neighbors_cleaning": range(3, 10, 2),
    "sampler__k_neighbors_borders": range(3, 10, 2),
    
    "classifier__n_neighbors": range(3, 18, 2),
}

# AdaBoostGNB
param_grid_AdaBoostGNB = {
    "preprocessor__num__imputer__n_neighbors": range(3, 16),
    
    "feature_selector__k": range(1, 21),
    
    "sampler__k_neighbors_cleaning": range(3, 10, 2),
    "sampler__k_neighbors_borders": range(3, 10, 2),
    
    "classifier__learning_rate": [0.8, 0.9, 1, 1.1, 1.2, 1.3, 1.4, 1.5],
}

# LogReg
param_grid_LogReg = {
    "preprocessor__num__imputer__n_neighbors": range(3, 16),
    
    "feature_selector__k": range(1, 21),
    
    "sampler__k_neighbors_cleaning": range(2, 9, 2),
    "sampler__k_neighbors_borders": range(2, 9, 2),
    
    "classifier__C": [0.01, 0.1, 1, 10, 100],
}

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
scorer = "f1_macro"

# %% [markdown]
# In the same way as in the CustomImputers, the plot function is retriving the indeces used in the fold to recreate and print all the steps that were performed by the RandomizedSearchCV, skf.split specify the fold and the indeces involved in the evaluation of the score.

# %%
clfrf = RandomizedSearchCV(
    estimator = clf_RandomForest, 
    param_distributions=param_grid_RandomForest,
    cv = skf,
    scoring = scorer,
    n_jobs=-1,
    random_state=0,
    n_iter=20,
)
clfrf.fit(X, y)

best_params = clfrf.best_params_
print("Random Forest best parameters:", best_params)

f_macro_scores1 = []
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
for fold, (train_index, test_index) in enumerate(skf.split(X, y)):
    X_fold_train, X_fold_valid = X.iloc[train_index], X.iloc[test_index]
    y_fold_train, y_fold_valid = y.iloc[train_index], y.iloc[test_index]

    y_pred = clfrf.predict(X_fold_valid)

    cm = confusion_matrix(y_fold_valid, y_pred)
    report = classification_report(y_fold_valid, y_pred, output_dict=False)
    print(report)
    report = classification_report(y_fold_valid, y_pred, output_dict=True)
    f_macro_scores1.append(report["macro avg"]["f1-score"])

    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', ax=axes[fold // 5, fold % 5])
    axes[fold // 5, fold % 5].set_title(f'Fold {fold+1}')
    axes[fold // 5, fold % 5].set_xlabel('Predicted')
    axes[fold // 5, fold % 5].set_ylabel('True')

plt.tight_layout()
plt.show()
# Out:
# Random Forest best parameters: {'sampler__k_neighbors_cleaning': 3, 'sampler__k_neighbors_borders': 7, 'preprocessor__num__imputer__n_neighbors': 11, 'feature_selector__k': 14, 'classifier__max_depth': 7, 'classifier__criterion': 'entropy'}
#                    precision    recall  f1-score   support
#
#       High chance       0.95      0.87      0.91        23
#        Low chance       0.84      0.94      0.89        17
# Transplant needed       1.00      1.00      1.00         2
#
#          accuracy                           0.90        42
#         macro avg       0.93      0.94      0.93        42
#      weighted avg       0.91      0.90      0.91        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.96      0.92      0.94        24
#        Low chance       1.00      0.94      0.97        16
# Transplant needed       0.50      1.00      0.67         2
#
#          accuracy                           0.93        42
#         macro avg       0.82      0.95      0.86        42
#      weighted avg       0.95      0.93      0.94        42
#
#                    precision    recall  f1-score   support
#
#       High chance       1.00      0.96      0.98        24
#        Low chance       0.94      1.00      0.97        16
# Transplant needed       1.00      1.00      1.00         2
#
#          accuracy                           0.98        42
#         macro avg       0.98      0.99      0.98        42
#      weighted avg       0.98      0.98      0.98        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.95      0.78      0.86        23
#        Low chance       0.79      0.94      0.86        16
# Transplant needed       0.75      1.00      0.86         3
#
#          accuracy                           0.86        42
#         macro avg       0.83      0.91      0.86        42
#      weighted avg       0.87      0.86      0.86        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.94      0.70      0.80        23
#        Low chance       0.68      0.94      0.79        16
# Transplant needed       1.00      1.00      1.00         3
#
#          accuracy                           0.81        42
#         macro avg       0.87      0.88      0.86        42
#      weighted avg       0.85      0.81      0.81        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.94      0.70      0.80        23
#        Low chance       0.70      1.00      0.82        16
# Transplant needed       1.00      0.67      0.80         3
#
#          accuracy                           0.81        42
#         macro avg       0.88      0.79      0.81        42
#      weighted avg       0.85      0.81      0.81        42
#
#                    precision    recall  f1-score   support
#
#       High chance       1.00      0.91      0.95        23
#        Low chance       0.94      1.00      0.97        16
# Transplant needed       0.75      1.00      0.86         3
#
#          accuracy                           0.95        42
#         macro avg       0.90      0.97      0.93        42
#      weighted avg       0.96      0.95      0.95        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.94      0.74      0.83        23
#        Low chance       0.74      0.88      0.80        16
# Transplant needed       0.60      1.00      0.75         3
#
#          accuracy                           0.81        42
#         macro avg       0.76      0.87      0.79        42
#      weighted avg       0.84      0.81      0.81        42
#
#                    precision    recall  f1-score   support
#
#       High chance       1.00      0.87      0.93        23
#        Low chance       0.84      1.00      0.91        16
# Transplant needed       1.00      1.00      1.00         2
#
#          accuracy                           0.93        41
#         macro avg       0.95      0.96      0.95        41
#      weighted avg       0.94      0.93      0.93        41
#
#                    precision    recall  f1-score   support
#
#       High chance       0.94      0.74      0.83        23
#        Low chance       0.75      0.94      0.83        16
# Transplant needed       0.67      1.00      0.80         2
#
#          accuracy                           0.83        41
#         macro avg       0.79      0.89      0.82        41
#      weighted avg       0.86      0.83      0.83        41

# %%
clfknn = RandomizedSearchCV(
    estimator = clf_KNNeighbor, 
    param_distributions=param_grid_KNNeighbor,
    cv = skf,
    scoring = scorer,
    n_jobs=-1,
    random_state=0,
    n_iter=20,
)
clfknn.fit(X, y)

best_params = clfknn.best_params_
print("KNN best parameters:", best_params)

f_macro_scores2 = []
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
for fold, (train_index, test_index) in enumerate(skf.split(X, y)):
    X_fold_train, X_fold_valid = X.iloc[train_index], X.iloc[test_index]
    y_fold_train, y_fold_valid = y.iloc[train_index], y.iloc[test_index]

    y_pred = clfknn.predict(X_fold_valid)

    cm = confusion_matrix(y_fold_valid, y_pred)
    report = classification_report(y_fold_valid, y_pred, output_dict=False)
    print(report)
    report = classification_report(y_fold_valid, y_pred, output_dict=True)
    f_macro_scores2.append(report["macro avg"]["f1-score"])

    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', ax=axes[fold // 5, fold % 5])
    axes[fold // 5, fold % 5].set_title(f'Fold {fold+1}')
    axes[fold // 5, fold % 5].set_xlabel('Predicted')
    axes[fold // 5, fold % 5].set_ylabel('True')

plt.tight_layout()
plt.show()
# Out:
# KNN best parameters: {'sampler__k_neighbors_cleaning': 7, 'sampler__k_neighbors_borders': 7, 'preprocessor__num__imputer__n_neighbors': 8, 'feature_selector__k': 11, 'classifier__n_neighbors': 9}
#                    precision    recall  f1-score   support
#
#       High chance       0.88      0.65      0.75        23
#        Low chance       0.83      0.59      0.69        17
# Transplant needed       0.15      1.00      0.27         2
#
#          accuracy                           0.64        42
#         macro avg       0.62      0.75      0.57        42
#      weighted avg       0.83      0.64      0.70        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.94      0.62      0.75        24
#        Low chance       0.83      0.62      0.71        16
# Transplant needed       0.14      1.00      0.25         2
#
#          accuracy                           0.64        42
#         macro avg       0.64      0.75      0.57        42
#      weighted avg       0.86      0.64      0.71        42
#
#                    precision    recall  f1-score   support
#
#       High chance       1.00      0.83      0.91        24
#        Low chance       0.81      0.81      0.81        16
# Transplant needed       0.33      1.00      0.50         2
#
#          accuracy                           0.83        42
#         macro avg       0.72      0.88      0.74        42
#      weighted avg       0.90      0.83      0.85        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.85      0.74      0.79        23
#        Low chance       0.64      0.56      0.60        16
# Transplant needed       0.38      1.00      0.55         3
#
#          accuracy                           0.69        42
#         macro avg       0.62      0.77      0.65        42
#      weighted avg       0.74      0.69      0.70        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.87      0.57      0.68        23
#        Low chance       0.63      0.75      0.69        16
# Transplant needed       0.12      0.33      0.18         3
#
#          accuracy                           0.62        42
#         macro avg       0.54      0.55      0.52        42
#      weighted avg       0.72      0.62      0.65        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.80      0.70      0.74        23
#        Low chance       0.65      0.69      0.67        16
# Transplant needed       0.40      0.67      0.50         3
#
#          accuracy                           0.69        42
#         macro avg       0.62      0.68      0.64        42
#      weighted avg       0.71      0.69      0.70        42
#
#                    precision    recall  f1-score   support
#
#       High chance       1.00      0.78      0.88        23
#        Low chance       0.91      0.62      0.74        16
# Transplant needed       0.23      1.00      0.38         3
#
#          accuracy                           0.74        42
#         macro avg       0.71      0.80      0.66        42
#      weighted avg       0.91      0.74      0.79        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.93      0.57      0.70        23
#        Low chance       0.76      0.81      0.79        16
# Transplant needed       0.27      1.00      0.43         3
#
#          accuracy                           0.69        42
#         macro avg       0.66      0.79      0.64        42
#      weighted avg       0.82      0.69      0.72        42
#
#                    precision    recall  f1-score   support
#
#       High chance       1.00      0.74      0.85        23
#        Low chance       0.76      0.81      0.79        16
# Transplant needed       0.14      0.50      0.22         2
#
#          accuracy                           0.76        41
#         macro avg       0.64      0.68      0.62        41
#      weighted avg       0.87      0.76      0.80        41
#
#                    precision    recall  f1-score   support
#
#       High chance       0.94      0.65      0.77        23
#        Low chance       0.91      0.62      0.74        16
# Transplant needed       0.14      1.00      0.25         2
#
#          accuracy                           0.66        41
#         macro avg       0.66      0.76      0.59        41
#      weighted avg       0.89      0.66      0.73        41

# %%
clfadagnb = RandomizedSearchCV(
    estimator = clf_AdaBoostGNB, 
    param_distributions=param_grid_AdaBoostGNB,
    cv = skf,
    scoring = scorer,
    n_jobs=-1,
    random_state=0,
    n_iter=20,
)
clfadagnb.fit(X, y)

best_params = clfadagnb.best_params_
print("AdaBoost best parameters:", best_params)

f_macro_scores3 = []
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
for fold, (train_index, test_index) in enumerate(skf.split(X, y)):
    X_fold_train, X_fold_valid = X.iloc[train_index], X.iloc[test_index]
    y_fold_train, y_fold_valid = y.iloc[train_index], y.iloc[test_index]

    y_pred = clfadagnb.predict(X_fold_valid)

    cm = confusion_matrix(y_fold_valid, y_pred)
    report = classification_report(y_fold_valid, y_pred, output_dict=False)
    print(report)
    report = classification_report(y_fold_valid, y_pred, output_dict=True)
    f_macro_scores3.append(report["macro avg"]["f1-score"])

    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', ax=axes[fold // 5, fold % 5])
    axes[fold // 5, fold % 5].set_title(f'Fold {fold+1}')
    axes[fold // 5, fold % 5].set_xlabel('Predicted')
    axes[fold // 5, fold % 5].set_ylabel('True')

plt.tight_layout()
plt.show()
# Out:
# AdaBoost best parameters: {'sampler__k_neighbors_cleaning': 9, 'sampler__k_neighbors_borders': 3, 'preprocessor__num__imputer__n_neighbors': 8, 'feature_selector__k': 11, 'classifier__learning_rate': 0.8}
#                    precision    recall  f1-score   support
#
#       High chance       0.88      0.65      0.75        23
#        Low chance       0.60      0.53      0.56        17
# Transplant needed       0.20      1.00      0.33         2
#
#          accuracy                           0.62        42
#         macro avg       0.56      0.73      0.55        42
#      weighted avg       0.74      0.62      0.65        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.83      0.62      0.71        24
#        Low chance       0.71      0.75      0.73        16
# Transplant needed       0.29      1.00      0.44         2
#
#          accuracy                           0.69        42
#         macro avg       0.61      0.79      0.63        42
#      weighted avg       0.76      0.69      0.71        42
#
#                    precision    recall  f1-score   support
#
#       High chance       1.00      0.75      0.86        24
#        Low chance       0.71      0.94      0.81        16
# Transplant needed       0.33      0.50      0.40         2
#
#          accuracy                           0.81        42
#         macro avg       0.68      0.73      0.69        42
#      weighted avg       0.86      0.81      0.82        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.84      0.70      0.76        23
#        Low chance       0.67      0.75      0.71        16
# Transplant needed       0.20      0.33      0.25         3
#
#          accuracy                           0.69        42
#         macro avg       0.57      0.59      0.57        42
#      weighted avg       0.73      0.69      0.70        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.87      0.57      0.68        23
#        Low chance       0.59      0.81      0.68        16
# Transplant needed       0.20      0.33      0.25         3
#
#          accuracy                           0.64        42
#         macro avg       0.55      0.57      0.54        42
#      weighted avg       0.71      0.64      0.65        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.78      0.61      0.68        23
#        Low chance       0.60      0.75      0.67        16
# Transplant needed       0.50      0.67      0.57         3
#
#          accuracy                           0.67        42
#         macro avg       0.63      0.68      0.64        42
#      weighted avg       0.69      0.67      0.67        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.94      0.70      0.80        23
#        Low chance       0.72      0.81      0.76        16
# Transplant needed       0.43      1.00      0.60         3
#
#          accuracy                           0.76        42
#         macro avg       0.70      0.84      0.72        42
#      weighted avg       0.82      0.76      0.77        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.94      0.65      0.77        23
#        Low chance       0.65      0.81      0.72        16
# Transplant needed       0.17      0.33      0.22         3
#
#          accuracy                           0.69        42
#         macro avg       0.58      0.60      0.57        42
#      weighted avg       0.77      0.69      0.71        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.95      0.83      0.88        23
#        Low chance       0.81      0.81      0.81        16
# Transplant needed       0.20      0.50      0.29         2
#
#          accuracy                           0.80        41
#         macro avg       0.65      0.71      0.66        41
#      weighted avg       0.86      0.80      0.83        41
#
#                    precision    recall  f1-score   support
#
#       High chance       0.94      0.65      0.77        23
#        Low chance       0.70      0.88      0.78        16
# Transplant needed       0.40      1.00      0.57         2
#
#          accuracy                           0.76        41
#         macro avg       0.68      0.84      0.71        41
#      weighted avg       0.82      0.76      0.76        41

# %%
clflr = RandomizedSearchCV(
    estimator = clf_LogReg, 
    param_distributions=param_grid_LogReg,
    cv = skf,
    scoring = scorer,
    n_jobs=-1,
    random_state=0,
    n_iter=20,
)
clflr.fit(X, y)

best_params = clflr.best_params_
print("Logistic Regression best parameters:", best_params)

f_macro_scores4 = []
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
for fold, (train_index, test_index) in enumerate(skf.split(X, y)):
    X_fold_train, X_fold_valid = X.iloc[train_index], X.iloc[test_index]
    y_fold_train, y_fold_valid = y.iloc[train_index], y.iloc[test_index]

    y_pred = clflr.predict(X_fold_valid)

    cm = confusion_matrix(y_fold_valid, y_pred)
    report = classification_report(y_fold_valid, y_pred, output_dict=False)
    print(report)
    report = classification_report(y_fold_valid, y_pred, output_dict=True)
    f_macro_scores4.append(report["macro avg"]["f1-score"])

    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', ax=axes[fold // 5, fold % 5])
    axes[fold // 5, fold % 5].set_title(f'Fold {fold+1}')
    axes[fold // 5, fold % 5].set_xlabel('Predicted')
    axes[fold // 5, fold % 5].set_ylabel('True')

plt.tight_layout()
plt.show()
# Out:
# Logistic Regression best parameters: {'sampler__k_neighbors_cleaning': 2, 'sampler__k_neighbors_borders': 2, 'preprocessor__num__imputer__n_neighbors': 9, 'feature_selector__k': 15, 'classifier__C': 100}
#                    precision    recall  f1-score   support
#
#       High chance       0.89      0.70      0.78        23
#        Low chance       0.73      0.65      0.69        17
# Transplant needed       0.22      1.00      0.36         2
#
#          accuracy                           0.69        42
#         macro avg       0.61      0.78      0.61        42
#      weighted avg       0.79      0.69      0.72        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.82      0.75      0.78        24
#        Low chance       0.79      0.69      0.73        16
# Transplant needed       0.17      0.50      0.25         2
#
#          accuracy                           0.71        42
#         macro avg       0.59      0.65      0.59        42
#      weighted avg       0.77      0.71      0.74        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.95      0.88      0.91        24
#        Low chance       0.88      0.88      0.88        16
# Transplant needed       0.50      1.00      0.67         2
#
#          accuracy                           0.88        42
#         macro avg       0.78      0.92      0.82        42
#      weighted avg       0.90      0.88      0.89        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.90      0.78      0.84        23
#        Low chance       0.69      0.69      0.69        16
# Transplant needed       0.33      0.67      0.44         3
#
#          accuracy                           0.74        42
#         macro avg       0.64      0.71      0.66        42
#      weighted avg       0.78      0.74      0.75        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.94      0.74      0.83        23
#        Low chance       0.68      0.81      0.74        16
# Transplant needed       0.40      0.67      0.50         3
#
#          accuracy                           0.76        42
#         macro avg       0.68      0.74      0.69        42
#      weighted avg       0.81      0.76      0.77        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.89      0.70      0.78        23
#        Low chance       0.67      0.88      0.76        16
# Transplant needed       0.67      0.67      0.67         3
#
#          accuracy                           0.76        42
#         macro avg       0.74      0.75      0.73        42
#      weighted avg       0.79      0.76      0.76        42
#
#                    precision    recall  f1-score   support
#
#       High chance       1.00      0.87      0.93        23
#        Low chance       0.93      0.81      0.87        16
# Transplant needed       0.25      0.67      0.36         3
#
#          accuracy                           0.83        42
#         macro avg       0.73      0.78      0.72        42
#      weighted avg       0.92      0.83      0.87        42
#
#                    precision    recall  f1-score   support
#
#       High chance       0.93      0.61      0.74        23
#        Low chance       0.68      0.81      0.74        16
# Transplant needed       0.38      1.00      0.55         3
#
#          accuracy                           0.71        42
#         macro avg       0.66      0.81      0.68        42
#      weighted avg       0.80      0.71      0.73        42
#
#                    precision    recall  f1-score   support
#
#       High chance       1.00      0.83      0.90        23
#        Low chance       0.83      0.94      0.88        16
# Transplant needed       0.25      0.50      0.33         2
#
#          accuracy                           0.85        41
#         macro avg       0.69      0.75      0.71        41
#      weighted avg       0.90      0.85      0.87        41
#
#                    precision    recall  f1-score   support
#
#       High chance       0.94      0.70      0.80        23
#        Low chance       0.88      0.88      0.88        16
# Transplant needed       0.25      1.00      0.40         2
#
#          accuracy                           0.78        41
#         macro avg       0.69      0.86      0.69        41
#      weighted avg       0.88      0.78      0.81        41

# %%
cv_scores = {
    'RandomForest': f_macro_scores1,
    'KNNeighbor': f_macro_scores2,
    'ADABOOST(NBC)': f_macro_scores3,
    'LogisticRegression': f_macro_scores4
}

df_cv_scores = pd.DataFrame(cv_scores)

df_cv_scores.boxplot()
plt.xticks(ticks=range(1, len(df_cv_scores.columns) + 1), labels=df_cv_scores.columns, rotation=90)
plt.tight_layout()
plt.savefig("stat_result NonSMOTENC.png")
plt.show()

# %%
import scipy.stats as stats

sns.kdeplot(data=df_cv_scores)
plt.tight_layout()
plt.savefig("NonSMOTENC KDE plot.png")
plt.show()
# Out:
# C:\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
for i, col in enumerate(df_cv_scores.columns):
    stats.probplot(df_cv_scores[col], plot=plt)
    plt.title(f'QQ Plot - {col}')
    plt.xlabel('Normal distribution quantiles')
    plt.ylabel('Data quantiles')
    plt.tight_layout()
    plt.savefig(f"NonSMOTENC_Test_QQ_Plot_{col}.png")

    plt.show()

# %%
statistic, p_value = stats.levene(cv_scores["RandomForest"], 
                                 cv_scores["KNNeighbor"], 
                                 cv_scores["ADABOOST(NBC)"], 
                                 cv_scores["LogisticRegression"])

print("Levene's statistic:", statistic)
print("p value:", p_value)

if p_value < 0.05:
    print("There is evidence to reject the null hypothesis of equal variances (homoscedasticity).")
else:
    print("There is no evidence to reject the null hypothesis of equal variances (homoscedasticity).")
# Out:
# Levene's statistic: 0.1621720253985203
# p value: 0.9211077886144717
# There is no evidence to reject the null hypothesis of equal variances (homoscedasticity).

# %%
from scipy.stats import kruskal
from itertools import combinations
from scipy.stats import wilcoxon

kruskal_result = kruskal(cv_scores["RandomForest"], 
                         cv_scores["KNNeighbor"], 
                         cv_scores["ADABOOST(NBC)"], 
                         cv_scores["LogisticRegression"])

print("Kruskal-Wallis statistic:", kruskal_result.statistic)
print("p value:", kruskal_result.pvalue)

if kruskal_result.pvalue < 0.05:
    print("There is a statistically relevant difference between at least two groups.")
    models = ["RandomForest", "KNNeighbor", "ADABOOST(NBC)", "LogisticRegression"]
    couples = list(combinations(models, 2))
    
    for _ in couples:
        m1, m2 = _
        wilcoxon_result = wilcoxon(cv_scores[m1], cv_scores[m2])
        
        print("Comparing", m1, "and", m2)
        print("Wilcoxon statistic:", wilcoxon_result.statistic)
        print("p value:", wilcoxon_result.pvalue)
        
        if wilcoxon_result.pvalue < 0.05:
            print("There is a statistically relevant difference between", m1, "and", m2)
        else:
            print("There is no statistically relevant difference between", m1, "and", m2)
        print("----")
else:
    print("There are no statistically relevant difference between groups.")
# Out:
# Kruskal-Wallis statistic: 24.914634146341484
# p value: 1.608825352331587e-05
# There is a statistically relevant difference between at least two groups.
# Comparing RandomForest and KNNeighbor
# Wilcoxon statistic: 0.0
# p value: 0.001953125
# There is a statistically relevant difference between RandomForest and KNNeighbor
# ----
# Comparing RandomForest and ADABOOST(NBC)
# Wilcoxon statistic: 0.0
# p value: 0.001953125
# There is a statistically relevant difference between RandomForest and ADABOOST(NBC)
# ----
# Comparing RandomForest and LogisticRegression
# Wilcoxon statistic: 0.0
# p value: 0.001953125
# There is a statistically relevant difference between RandomForest and LogisticRegression
# ----
# Comparing KNNeighbor and ADABOOST(NBC)
# Wilcoxon statistic: 24.0
# p value: 0.76953125
# There is no statistically relevant difference between KNNeighbor and ADABOOST(NBC)
# ----
# Comparing KNNeighbor and LogisticRegression
# Wilcoxon statistic: 0.0
# p value: 0.001953125
# There is a statistically relevant difference between KNNeighbor and LogisticRegression
# ----
# Comparing ADABOOST(NBC) and LogisticRegression
# Wilcoxon statistic: 6.0
# p value: 0.02734375
# There is a statistically relevant difference between ADABOOST(NBC) and LogisticRegression
# ----

# %%
np.save("RandomForestNonSMOTENC.npy", cv_scores["RandomForest"])
